# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2=pd.read_excel("Clean Scrapped_Data.xls")
df2
# Out:
#                                          Product Name   Price  Discount  \
# 0   Mi 4A PRO 80 cm (32 inch) HD Ready LED Smart A...   15999        20
# 1   Mi 4X 108 cm (43 inch) Ultra HD (4K) LED Smart...   28999        17
# 2   Mi 4A Horizon Edition 100 cm (40 inch) Full HD...   23999        20
# 3   Mi 4A 100 cm (40 inch) Full HD LED Smart Andro...   23999         4
# 4   Mi 4X 125.7 cm (50 inch) Ultra HD (4K) LED Sma...   36999        11
# 5   Mi 4A Horizon Edition 80 cm (32 inch) HD Ready...   16999        15
# 6   Mi 4X 138.8 cm (55 inch) Ultra HD (4K) LED Sma...   42999        14
# 7   Mi 4A Horizon Edition 108 cm (43 inch) Full HD...   26999        15
# 8   Mi Q1 138.8 cm (55 inch) QLED Ultra HD (4K) Sm...   58999         1
# 9   Mi Q1 189.34 cm (75 inch) QLED Ultra HD (4K) S...  127999        36
# 10  Mi 4A PRO 80 cm (32 inch) HD Ready LED Smart A...   18990         5
# 11  Mi 4C 80 cm (32 inch) HD Ready LED Smart Andro...   15999        20
# ...

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.barplot(df2['Product Name'],df2.Price)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product Name', ylabel='Price'>

# %%
sns.barplot(df2.Price,df2['Product Name'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Product Name'>

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.barplot(df2['Product Name'],df2.Price,hue=df2['Rating'] )
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product Name', ylabel='Price'>

# %%
plt.figure(figsize=(20,10))

sns.countplot(df2['Rating'], hue=df2['Discount'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
pd.crosstab(df2['Rating'],df2['Discount'])
# Out:
# Discount  0   1   2   4   5   10  11  14  15  17  20  36
# Rating
# 4.3        0   0   0   0   0   0   0   0   2   0   1   0
# 4.4        3   1   1   1   1   1   1   1   0   1   2   1

# %%
sns.distplot(df2.Price)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>
